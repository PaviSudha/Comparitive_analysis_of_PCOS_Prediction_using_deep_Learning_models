# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
from sklearn import svm, metrics
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# Import label encoder
from sklearn import preprocessing

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import random
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, LSTM, RepeatVector, TimeDistributed

from keras.layers import Layer
from keras import backend as K
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# Import Dataset

# %%
df = pd.read_csv('data/cleaned_data1.csv')

# %%
X = df.drop(columns=["PCOS (Y/N)"])
y = df["PCOS (Y/N)"].values

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)
X.shape
# Out:
# (529, 37)

# %%
from sklearn.manifold import Isomap

isomap = Isomap(n_neighbors=5, n_components=10, 
                eigen_solver='auto')
X = isomap.fit_transform(X)

# %%
sns.scatterplot(X[:,0], X[:,1], hue=y, palette='Set1')
plt.title("ISOMAP", fontsize=15)
plt.xlabel("ISOMAP1", fontsize=12)
plt.ylabel("ISOMAP2", fontsize=12)
# Out:
# C:\Users\pavithra\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'ISOMAP2')

# %%
#split dataset into train and test data
train_features, test_features, train_target, test_target = train_test_split(X,y,test_size=0.33, random_state=13)

# %%
class RBFLayer(Layer):
    def __init__(self, units, gamma, **kwargs):
        super(RBFLayer, self).__init__(**kwargs)
        self.units = units
        self.gamma = K.cast_to_floatx(gamma)

    def build(self, input_shape):
#         print(input_shape)
#         print(self.units)
        self.mu = self.add_weight(name='mu',
                                  shape=(int(input_shape[1]), self.units),
                                  initializer='uniform',
                                  trainable=True)
        super(RBFLayer, self).build(input_shape)

    def call(self, inputs):
        diff = K.expand_dims(inputs) - self.mu
        l2 = K.sum(K.pow(diff, 2), axis=1)
        res = K.exp(-1 * self.gamma * l2)
        return res

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.units)

# %%
model = Sequential()
model.add(Dense(10, input_dim=10, activation='relu'))
model.add(RBFLayer(10, 0.3))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(train_features,train_target,validation_data=(test_features,test_target),epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 0s 17ms/step - loss: 0.6922 - accuracy: 0.6610 - val_loss: 0.6913 - val_accuracy: 0.6571
# Epoch 2/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6903 - accuracy: 0.6836 - val_loss: 0.6896 - val_accuracy: 0.6571
# Epoch 3/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6880 - accuracy: 0.6836 - val_loss: 0.6879 - val_accuracy: 0.6571
# Epoch 4/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6859 - accuracy: 0.6836 - val_loss: 0.6859 - val_accuracy: 0.6571
# Epoch 5/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6834 - accuracy: 0.6836 - val_loss: 0.6836 - val_accuracy: 0.6571
# Epoch 6/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6809 - accuracy: 0.6836 - val_loss: 0.6811 - val_accuracy: 0.6571
# Epoch 7/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6776 - accuracy: 0.6836 - val_loss: 0.6772 - val_accuracy: 0.6571
# Epoch 8/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6734 - accuracy: 0.6836 - val_loss: 0.6725 - val_accuracy: 0.6571
# Epoch 9/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6672 - accuracy: 0.6836 - val_loss: 0.6671 - val_accuracy: 0.6571
# Epoch 10/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6597 - accuracy: 0.6836 - val_loss: 0.6609 - val_accuracy: 0.6571
# Epoch 11/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6505 - accuracy: 0.6836 - val_loss: 0.6543 - val_accuracy: 0.6571
# Epoch 12/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6416 - accuracy: 0.6836 - val_loss: 0.6484 - val_accuracy: 0.6571
# Epoch 13/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6322 - accuracy: 0.6836 - val_loss: 0.6420 - val_accuracy: 0.6571
# Epoch 14/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6226 - accuracy: 0.6836 - val_loss: 0.6355 - val_accuracy: 0.6571
# Epoch 15/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6124 - accuracy: 0.6836 - val_loss: 0.6282 - val_accuracy: 0.6571
# Epoch 16/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6024 - accuracy: 0.6836 - val_loss: 0.6215 - val_accuracy: 0.6571
# Epoch 17/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5937 - accuracy: 0.6836 - val_loss: 0.6148 - val_accuracy: 0.6571
# Epoch 18/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5849 - accuracy: 0.6836 - val_loss: 0.6081 - val_accuracy: 0.6571
# Epoch 19/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5766 - accuracy: 0.6836 - val_loss: 0.6003 - val_accuracy: 0.6571
# Epoch 20/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5668 - accuracy: 0.6836 - val_loss: 0.5934 - val_accuracy: 0.6571
# Epoch 21/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5589 - accuracy: 0.6836 - val_loss: 0.5871 - val_accuracy: 0.6571
# Epoch 22/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5510 - accuracy: 0.6836 - val_loss: 0.5817 - val_accuracy: 0.6571
# Epoch 23/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5439 - accuracy: 0.6836 - val_loss: 0.5761 - val_accuracy: 0.6571
# Epoch 24/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5357 - accuracy: 0.6836 - val_loss: 0.5709 - val_accuracy: 0.6571
# Epoch 25/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5279 - accuracy: 0.6836 - val_loss: 0.5657 - val_accuracy: 0.6571
# Epoch 26/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5203 - accuracy: 0.6836 - val_loss: 0.5612 - val_accuracy: 0.6571
# Epoch 27/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5139 - accuracy: 0.6836 - val_loss: 0.5575 - val_accuracy: 0.6571
# Epoch 28/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5083 - accuracy: 0.6836 - val_loss: 0.5539 - val_accuracy: 0.6571
# Epoch 29/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5034 - accuracy: 0.6836 - val_loss: 0.5510 - val_accuracy: 0.6571
# Epoch 30/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4994 - accuracy: 0.6836 - val_loss: 0.5482 - val_accuracy: 0.6571
# Epoch 31/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4957 - accuracy: 0.6836 - val_loss: 0.5464 - val_accuracy: 0.6571
# Epoch 32/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4921 - accuracy: 0.6836 - val_loss: 0.5441 - val_accuracy: 0.6571
# Epoch 33/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4886 - accuracy: 0.6836 - val_loss: 0.5422 - val_accuracy: 0.6571
# Epoch 34/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4853 - accuracy: 0.6836 - val_loss: 0.5407 - val_accuracy: 0.6571
# Epoch 35/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4821 - accuracy: 0.6836 - val_loss: 0.5386 - val_accuracy: 0.6571
# Epoch 36/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4793 - accuracy: 0.6836 - val_loss: 0.5368 - val_accuracy: 0.6571
# Epoch 37/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4770 - accuracy: 0.6836 - val_loss: 0.5344 - val_accuracy: 0.6571
# Epoch 38/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4747 - accuracy: 0.6836 - val_loss: 0.5331 - val_accuracy: 0.6571
# Epoch 39/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4725 - accuracy: 0.6836 - val_loss: 0.5317 - val_accuracy: 0.6571
# Epoch 40/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4703 - accuracy: 0.6836 - val_loss: 0.5302 - val_accuracy: 0.6571
# Epoch 41/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4680 - accuracy: 0.6836 - val_loss: 0.5280 - val_accuracy: 0.6571
# Epoch 42/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4656 - accuracy: 0.6836 - val_loss: 0.5260 - val_accuracy: 0.6571
# Epoch 43/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4633 - accuracy: 0.6836 - val_loss: 0.5233 - val_accuracy: 0.6571
# Epoch 44/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4614 - accuracy: 0.6836 - val_loss: 0.5208 - val_accuracy: 0.6571
# Epoch 45/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4590 - accuracy: 0.6836 - val_loss: 0.5183 - val_accuracy: 0.6571
# Epoch 46/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4565 - accuracy: 0.6836 - val_loss: 0.5151 - val_accuracy: 0.6571
# Epoch 47/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4536 - accuracy: 0.6836 - val_loss: 0.5113 - val_accuracy: 0.6571
# Epoch 48/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4502 - accuracy: 0.6836 - val_loss: 0.5076 - val_accuracy: 0.6571
# Epoch 49/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4457 - accuracy: 0.6836 - val_loss: 0.5024 - val_accuracy: 0.6571
# Epoch 50/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4416 - accuracy: 0.6836 - val_loss: 0.4979 - val_accuracy: 0.6571
# Epoch 51/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4381 - accuracy: 0.6836 - val_loss: 0.4942 - val_accuracy: 0.6571
# Epoch 52/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4349 - accuracy: 0.6836 - val_loss: 0.4911 - val_accuracy: 0.6571
# Epoch 53/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4325 - accuracy: 0.6836 - val_loss: 0.4874 - val_accuracy: 0.6571
# Epoch 54/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4292 - accuracy: 0.6836 - val_loss: 0.4845 - val_accuracy: 0.6571
# Epoch 55/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4268 - accuracy: 0.6836 - val_loss: 0.4803 - val_accuracy: 0.6571
# Epoch 56/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4231 - accuracy: 0.6836 - val_loss: 0.4757 - val_accuracy: 0.6571
# Epoch 57/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4186 - accuracy: 0.6836 - val_loss: 0.4705 - val_accuracy: 0.6571
# Epoch 58/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4140 - accuracy: 0.6836 - val_loss: 0.4657 - val_accuracy: 0.6571
# Epoch 59/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4095 - accuracy: 0.6836 - val_loss: 0.4603 - val_accuracy: 0.6571
# Epoch 60/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4054 - accuracy: 0.6836 - val_loss: 0.4541 - val_accuracy: 0.6571
# Epoch 61/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4004 - accuracy: 0.6836 - val_loss: 0.4496 - val_accuracy: 0.6571
# Epoch 62/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3954 - accuracy: 0.6836 - val_loss: 0.4454 - val_accuracy: 0.6571
# Epoch 63/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3914 - accuracy: 0.6836 - val_loss: 0.4409 - val_accuracy: 0.6571
# Epoch 64/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3875 - accuracy: 0.6836 - val_loss: 0.4377 - val_accuracy: 0.6571
# Epoch 65/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3839 - accuracy: 0.6836 - val_loss: 0.4379 - val_accuracy: 0.6571
# Epoch 66/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3814 - accuracy: 0.6836 - val_loss: 0.4363 - val_accuracy: 0.6571
# Epoch 67/100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.3785 - accuracy: 0.6836 - val_loss: 0.4338 - val_accuracy: 0.6571
# Epoch 68/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3760 - accuracy: 0.6836 - val_loss: 0.4321 - val_accuracy: 0.6571
# Epoch 69/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3737 - accuracy: 0.6836 - val_loss: 0.4297 - val_accuracy: 0.6571
# Epoch 70/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3707 - accuracy: 0.6836 - val_loss: 0.4283 - val_accuracy: 0.6571
# Epoch 71/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3676 - accuracy: 0.6836 - val_loss: 0.4262 - val_accuracy: 0.6571
# Epoch 72/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3650 - accuracy: 0.6836 - val_loss: 0.4242 - val_accuracy: 0.6571
# Epoch 73/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3619 - accuracy: 0.6836 - val_loss: 0.4227 - val_accuracy: 0.6571
# Epoch 74/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3593 - accuracy: 0.6836 - val_loss: 0.4219 - val_accuracy: 0.6571
# Epoch 75/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3568 - accuracy: 0.6836 - val_loss: 0.4202 - val_accuracy: 0.6571
# Epoch 76/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3541 - accuracy: 0.6836 - val_loss: 0.4196 - val_accuracy: 0.6571
# Epoch 77/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3518 - accuracy: 0.6836 - val_loss: 0.4186 - val_accuracy: 0.6571
# Epoch 78/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3499 - accuracy: 0.6836 - val_loss: 0.4183 - val_accuracy: 0.6571
# Epoch 79/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3478 - accuracy: 0.6836 - val_loss: 0.4171 - val_accuracy: 0.6571
# Epoch 80/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3457 - accuracy: 0.6836 - val_loss: 0.4160 - val_accuracy: 0.6571
# Epoch 81/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3438 - accuracy: 0.8390 - val_loss: 0.4151 - val_accuracy: 0.8971
# Epoch 82/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3420 - accuracy: 0.8588 - val_loss: 0.4144 - val_accuracy: 0.9086
# Epoch 83/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3411 - accuracy: 0.8503 - val_loss: 0.4143 - val_accuracy: 0.9029
# Epoch 84/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3401 - accuracy: 0.8503 - val_loss: 0.4131 - val_accuracy: 0.8971
# Epoch 85/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3388 - accuracy: 0.8446 - val_loss: 0.4150 - val_accuracy: 0.8971
# Epoch 86/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3368 - accuracy: 0.8475 - val_loss: 0.4142 - val_accuracy: 0.8914
# Epoch 87/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3352 - accuracy: 0.8503 - val_loss: 0.4125 - val_accuracy: 0.8857
# Epoch 88/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3339 - accuracy: 0.8531 - val_loss: 0.4114 - val_accuracy: 0.8857
# Epoch 89/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3319 - accuracy: 0.8531 - val_loss: 0.4098 - val_accuracy: 0.8857
# Epoch 90/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3303 - accuracy: 0.8531 - val_loss: 0.4094 - val_accuracy: 0.8857
# Epoch 91/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3284 - accuracy: 0.8559 - val_loss: 0.4080 - val_accuracy: 0.8914
# Epoch 92/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3267 - accuracy: 0.8503 - val_loss: 0.4063 - val_accuracy: 0.8857
# Epoch 93/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3258 - accuracy: 0.8531 - val_loss: 0.4052 - val_accuracy: 0.8857
# Epoch 94/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3245 - accuracy: 0.8559 - val_loss: 0.4045 - val_accuracy: 0.8857
# Epoch 95/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3233 - accuracy: 0.8503 - val_loss: 0.4032 - val_accuracy: 0.8857
# Epoch 96/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3221 - accuracy: 0.8503 - val_loss: 0.4027 - val_accuracy: 0.8857
# Epoch 97/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3209 - accuracy: 0.8475 - val_loss: 0.4028 - val_accuracy: 0.8914
# Epoch 98/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3198 - accuracy: 0.8531 - val_loss: 0.4017 - val_accuracy: 0.8914
# Epoch 99/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3185 - accuracy: 0.8531 - val_loss: 0.4021 - val_accuracy: 0.8914
# Epoch 100/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3172 - accuracy: 0.8559 - val_loss: 0.4022 - val_accuracy: 0.8914

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                110
# _________________________________________________________________
# rbf_layer (RBFLayer)         (None, 10)                100
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train','Validation'],loc='upper right')
plt.show()

# %%
plt.plot(history.history['accuracy'],label='Training accuracy')
plt.plot(history.history['val_accuracy'],label='Validation accuracy')
plt.title('Model accuracy')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train','Validation'],loc='upper right')
plt.show()

# %%
loss, acc = model.evaluate(test_features, test_target, verbose=0)
print('Test Accuracy: %.3f' %(acc * 100.0))
# Out:
# Test Accuracy: 84.000

# %%
from sklearn.metrics import classification_report, confusion_matrix

prediction = model.predict(test_features)
data = []
for x in prediction:
    # if the weights >0.5 then classified as 1 else classified as 0
    if x[0] > 0.5:
        data.append(1)
    else:
        data.append(0)

cnf_matrix = confusion_matrix(test_target, data)
cnf_matrix
# Out:
# array([[92, 23],
#        [ 5, 55]], dtype=int64)

# %%
print('Radial Basis Function Network: \n', classification_report(test_target, data),'\n')
# Out:
# Radial Basis Function Network:
#                precision    recall  f1-score   support
#
#            0       0.95      0.80      0.87       115
#            1       0.71      0.92      0.80        60
#
#     accuracy                           0.84       175
#    macro avg       0.83      0.86      0.83       175
# weighted avg       0.87      0.84      0.84       175

# %%
#Validation

from sklearn.metrics import mean_squared_error
from math import sqrt

#calculate RMSE
RMSE_test = sqrt(mean_squared_error(test_target, prediction)) 

#Traning

from sklearn.metrics import mean_squared_error
from math import sqrt
train_prediction = model.predict(train_features)
#calculate RMSE
RMSE_train = sqrt(mean_squared_error(train_target, train_prediction))

print('Traning RMSE: %.4f'%RMSE_train)
print('\n')
print('Testing RMSE: %.4f'%RMSE_test)
# Out:
# Traning RMSE: 0.3533
#
#
# Testing RMSE: 0.3652

# %%
#Validation

from sklearn.metrics import mean_absolute_error
from math import sqrt

#calculate RMSE
MAE_test = mean_absolute_error(test_target, prediction)

#Traning

from sklearn.metrics import mean_squared_error
from math import sqrt
train_prediction = model.predict(train_features)
#calculate RMSE
MAE_train = sqrt(mean_squared_error(train_target, train_prediction))

print('Traning MAE: %.4f'%MAE_train)
print('\n')
print('Testing MAE: %.4f'%MAE_test)
# Out:
# Traning MAE: 0.3533
#
#
# Testing MAE: 0.2694
