# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
from sklearn import svm, metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Dataset

# %%
data = pd.read_csv('data/cleaned_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b725db1f4078> in <module>
# ----> 1 data = pd.read_csv('data/cleaned_data.csv')
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # Dropping irrelevant freatures

# %%
data = data.drop(['Pregnant(Y/N)','PCOS (Y/N)','Weight gain(Y/N)','hair growth(Y/N)','Skin darkening (Y/N)','Skin darkening (Y/N)','Hair loss(Y/N)','Pimples(Y/N)','Fast food (Y/N)','Reg.Exercise(Y/N)'],axis=1)
data.head()
# Out:
#     Age (yrs)  Weight (Kg)  Height(Cm)         BMI  Blood Group  \
# 0          28         44.6        152.0  19.300000           15
# 1          36         65.0        161.5  24.921163           15
# 2          33         68.8        165.0  25.270891           11
# 3          37         65.0        148.0  29.674945           13
# 4          25         52.0        161.0  20.060954           11
#
#    Pulse rate(bpm)   RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  \
# 0                78                22     10.48           2
# 1                74                20     11.70           2
# 2                72                18     11.80           2
# 3                72                20     12.00           2
# 4                72                18     10.00           2
#
#    Cycle length(days)  ...  Vit D3 (ng/mL)  PRG(ng/mL)  RBS(mg/dl)  \
# 0                   5  ...            17.1        0.57        92.0
# 1                   5  ...            61.3        0.97        92.0
# 2                   5  ...            49.7        0.36        84.0
# 3                   5  ...            33.4        0.36        76.0
# 4                   5  ...            43.8        0.38        84.0
#
#    BP _Systolic (mmHg)  BP _Diastolic (mmHg)  Follicle No. (L)  \
# 0                  110                    80                 3
# 1                  120                    70                 3
# 2                  120                    80                13
# 3                  120                    70                 2
# 4                  120                    80                 3
#
#    Follicle No. (R)  Avg. F size (L) (mm)  Avg. F size (R) (mm)  \
# 0                 3                  18.0                  18.0
# 1                 5                  15.0                  14.0
# 2                15                  18.0                  20.0
# 3                 2                  15.0                  14.0
# 4                 4                  16.0                  14.0
#
#    Endometrium (mm)
# 0               8.5
# 1               3.7
# 2              10.0
# 3               7.5
# 4               7.0
#
# [5 rows x 29 columns]

# %%
data.hist(figsize=(16,20))
# Out:
# array([[<AxesSubplot:title={'center':' Age (yrs)'}>,
#         <AxesSubplot:title={'center':'Weight (Kg)'}>,
#         <AxesSubplot:title={'center':'Height(Cm) '}>,
#         <AxesSubplot:title={'center':'BMI'}>,
#         <AxesSubplot:title={'center':'Blood Group'}>],
#        [<AxesSubplot:title={'center':'Pulse rate(bpm) '}>,
#         <AxesSubplot:title={'center':'RR (breaths/min)'}>,
#         <AxesSubplot:title={'center':'Hb(g/dl)'}>,
#         <AxesSubplot:title={'center':'Cycle(R/I)'}>,
#         <AxesSubplot:title={'center':'Cycle length(days)'}>],
#        [<AxesSubplot:title={'center':'Marraige Status (Yrs)'}>,
#         <AxesSubplot:title={'center':'No. of aborptions'}>,
#         <AxesSubplot:title={'center':'FSH(mIU/mL)'}>,
#         <AxesSubplot:title={'center':'LH(mIU/mL)'}>,
#         <AxesSubplot:title={'center':'Hip(inch)'}>],
#        [<AxesSubplot:title={'center':'Waist(inch)'}>,
#         <AxesSubplot:title={'center':'TSH (mIU/L)'}>,
#         <AxesSubplot:title={'center':'AMH(ng/mL)'}>,
#         <AxesSubplot:title={'center':'PRL(ng/mL)'}>,
#         <AxesSubplot:title={'center':'Vit D3 (ng/mL)'}>],
#        [<AxesSubplot:title={'center':'PRG(ng/mL)'}>,
#         <AxesSubplot:title={'center':'RBS(mg/dl)'}>,
#         <AxesSubplot:title={'center':'BP _Systolic (mmHg)'}>,
#         <AxesSubplot:title={'center':'BP _Diastolic (mmHg)'}>,
#         <AxesSubplot:title={'center':'Follicle No. (L)'}>],
#        [<AxesSubplot:title={'center':'Follicle No. (R)'}>,
#         <AxesSubplot:title={'center':'Avg. F size (L) (mm)'}>,
#         <AxesSubplot:title={'center':'Avg. F size (R) (mm)'}>,
#         <AxesSubplot:title={'center':'Endometrium (mm)'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
#Plot Correlation Matrix
plt.figure(figsize=(20,8))
sns.heatmap(data.corr(), annot=True,cmap='YlGnBu')
Cplt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ae76364b1a91> in <module>
#       1 import seaborn as sns
# ----> 2 sns.lmplot(data =data,x='Follicle No. (R)',y='Follicle No. (L)', hue="PCOS (Y/N)",palette=color)
#       3 plt.show()
#
# NameError: name 'data' is not defined
